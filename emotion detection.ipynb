# %%
# !pip install deepface
# !pip install tf_keras
# !pip install opencv-python
cv2.VideoCapture()
# Out:
# Requirement already satisfied: deepface in c:\users\bharg\anaconda3\lib\site-packages (0.0.91)
# Requirement already satisfied: requests>=2.27.1 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (2.0.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (4.9.0.80)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (2.16.1)
# Requirement already satisfied: keras>=2.2.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (3.3.3)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (0.6.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\bharg\anaconda3\lib\site-packages (from deepface) (22.0.0)
# Requirement already satisfied: six in c:\users\bharg\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\bharg\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\bharg\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\bharg\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\bharg\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\bharg\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\bharg\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\bharg\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.9.0)
# Requirement already satisfied: packaging in c:\users\bharg\anaconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: absl-py in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (13.7.1)
# Requirement already satisfied: namex in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\bharg\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bharg\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bharg\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bharg\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bharg\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bharg\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bharg\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bharg\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2023.7.22)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.16.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (68.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (1.63.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\bharg\anaconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bharg\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bharg\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\bharg\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bharg\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bharg\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bharg\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bharg\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bharg\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: tf_keras in c:\users\bharg\anaconda3\lib\site-packages (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in c:\users\bharg\anaconda3\lib\site-packages (from tf_keras) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow<2.17,>=2.16->tf_keras) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.3.0)
# Requirement already satisfied: packaging in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.63.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\bharg\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.24.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bharg\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.38.4)
# Requirement already satisfied: rich in c:\users\bharg\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\bharg\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\bharg\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bharg\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bharg\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bharg\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bharg\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bharg\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\bharg\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bharg\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\bharg\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bharg\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bharg\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bharg\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.1.0)

# %%
import warnings
import cv2
from deepface import DeepFace
warnings.filterwarnings("ignore", category=DeprecationWarning)


face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = cap.read()
    
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        
        
        face = frame[y:y+h, x:x+w]
        
        
        result = DeepFace.analyze(face, actions=['emotion'], enforce_detection=False)
        
        
        if isinstance(result, list) and result:
           
            emotion = result[0]['dominant_emotion']
            
            cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
    
    cv2.imshow('Face Emotion Detection', frame)
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
